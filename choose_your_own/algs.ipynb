# %%
import matplotlib.pyplot as plt
from prep_terrain_data import makeTerrainData
from class_vis import prettyPicture

# %%
features_train, labels_train, features_test, labels_test = makeTerrainData()

# %%
len(features_train)
# Out:
# 750

# %%
len(features_train[0])
# Out:
# 2

# %%
grade_fast = [features_train[ii][0] for ii in range(0, len(features_train)) if labels_train[ii]==0]
bumpy_fast = [features_train[ii][1] for ii in range(0, len(features_train)) if labels_train[ii]==0]
grade_slow = [features_train[ii][0] for ii in range(0, len(features_train)) if labels_train[ii]==1]
bumpy_slow = [features_train[ii][1] for ii in range(0, len(features_train)) if labels_train[ii]==1]

# %%
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.scatter(bumpy_fast, grade_fast, color = "b", label="fast")
plt.scatter(grade_slow, bumpy_slow, color = "r", label="slow")
plt.legend()
plt.xlabel("bumpiness")
plt.ylabel("grade")
plt.show()

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_3 = KNeighborsClassifier(n_neighbors=3)

# %%
knn_3.fit(features_train, labels_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
acc_knn_3 = knn_3.score(features_test, labels_test)

# %%
print("Accuracy of KNN with number of neigh. equals 3:", acc_knn_3)
# Out:
# ('Accuracy of KNN with number of neigh. equals 3:', 0.936)

# %%
prettyPicture(knn_3, features_test, labels_test)

# %%
knn_5 = KNeighborsClassifier(n_neighbors=5)

# %%
knn_5.fit(features_train, labels_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
acc_knn_5 = knn_5.score(features_test, labels_test)

# %%
print("Accuracy of KNN with number of neigh. equals 5:", acc_knn_5)
# Out:
# ('Accuracy of KNN with number of neigh. equals 5:', 0.92)

# %%
prettyPicture(knn_5, features_test, labels_test)

# %%
knn_2 = KNeighborsClassifier(n_neighbors=2)

# %%
knn_2.fit(features_train, labels_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#            weights='uniform')

# %%
acc_knn_2 = knn_2.score(features_test, labels_test)

# %%
print("Accuracy of KNN with number of neigh. equals 2:", acc_knn_2)
# Out:
# ('Accuracy of KNN with number of neigh. equals 2:', 0.928)

# %%
prettyPicture(knn_2, features_test, labels_test)

# %%
knn_10 = KNeighborsClassifier(n_neighbors=10)

# %%
knn_10.fit(features_train, labels_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#            weights='uniform')

# %%
acc_knn_10 = knn_10.score(features_test, labels_test)

# %%
print("Accuracy of KNN with number of neigh. equals 10:", acc_knn_10)
# Out:
# ('Accuracy of KNN with number of neigh. equals 10:', 0.932)

# %%
prettyPicture(knn_10, features_test, labels_test)

# %%
knn_15 = KNeighborsClassifier(n_neighbors=15)

# %%
knn_15.fit(features_train, labels_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#            weights='uniform')

# %%
acc_knn_15 = knn_15.score(features_test, labels_test)

# %%
print("Accuracy of KNN with number of neigh. equals 15:", acc_knn_15)
# Out:
# ('Accuracy of KNN with number of neigh. equals 15:', 0.928)

# %%
prettyPicture(knn_15, features_test, labels_test)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=100)

# %%
clf.fit(features_train, labels_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
clf.score(features_test, labels_test)
# Out:
# 0.92

# %%
prettyPicture(clf, features_test, labels_test)

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()

# %%
ada.fit(features_train, labels_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
ada.score(features_test, labels_test)
# Out:
# 0.924

# %%
prettyPicture(ada, features_test, labels_test)
